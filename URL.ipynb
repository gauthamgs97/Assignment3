# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import re

# %%
data = pd.read_csv('phishing_dataset.csv', header = None)
data.columns=['Raw_URL']


adata = pd.read_csv('spam_dataset.csv',sep=',')
adata.columns=['Raw_URL']

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  return count
data['Len_URL']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  return count
adata['Len_URL']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    if(i=='/'):
      count=count+1
  return count
data['#_/']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    if(i=='/'):
      count=count+1
  return count
adata['#_/']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='/'):
      count2=count2+1
  x = count2/count
  return x
  

data['Ratio_/_Len']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='/'):
      count2=count2+1
  x = count2/count
  return x
  

adata['Ratio_/_Len']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    if(i=='-'):
      count=count+1
  return count
data['#_-']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    if(i=='-'):
      count=count+1
  return count
adata['#_-']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='-'):
      count2=count2+1
  x = count2/count
  return x
  

data['Ratio_-_Len']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='-'):
      count2=count2+1
  x = count2/count
  return x
  

adata['Ratio_-_Len']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    if(i=='.'):
      count=count+1
  return count
data['#_.']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    if(i=='.'):
      count=count+1
  return count
adata['#_.']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='.'):
      count2=count2+1
  x = count2/count
  return x
  

data['Ratio_._Len']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='.'):
      count2=count2+1
  x = count2/count
  return x
  

adata['Ratio_._Len']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=1
  for i in y:
    if(i=='.' or i== '-' or i=='/' or i==';' or i=='=' or i=='&' or i=='%'):
      count=count+1
  return count
data['URL_Token']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count=1
  for i in y:
    if(i=='.' or i== '-' or i=='/' or i==';' or i=='=' or i=='&' or i=='%'):
      count=count+1
  return count
adata['URL_Token']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    x = re.search('[A-Z]',i)
    if(x):
      count=count+1
  return count
  


data['URL_Caps']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    x = re.search('[A-Z]',i)
    if(x):
      count=count+1
  return count
  


adata['URL_Caps']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    q = re.search('[A-Z]',i)
    if(q):
      count2=count2+1
  x = count2/count
  return x
  

data['Ratio_Caps_Len']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    q = re.search('[A-Z]',i)
    if(q):
      count2=count2+1
  x = count2/count
  return x
  

adata['Ratio_Caps_Len']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    x = re.search('[a-z]',i)
    if(x):
      count=count+1
  return count
  


data['URL_Small']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    x = re.search('[a-z]',i)
    if(x):
      count=count+1
  return count
  


adata['URL_Small']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    q = re.search('[a-z]',i)
    if(q):
      count2=count2+1
  x = count2/count
  return x
  

data['Ratio_Small_Len']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    q = re.search('[a-z]',i)
    if(q):
      count2=count2+1
  x = count2/count
  return x
  

adata['Ratio_Small_Len']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count =0
  for i in y:
    if(i.isdigit()):
      count=count+1
  return count
         
      
data['No_of_digits']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count =0
  for i in y:
    if(i.isdigit()):
      count=count+1
  return count
         
      
adata['No_of_digits']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i.isdigit()):
      count2=count2+1
  x = count2/count
  return x
  

data['Ratio_Digits_Len']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i.isdigit()):
      count2=count2+1
  x = count2/count
  return x
  

adata['Ratio_Digits_Len']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count =0
  for i in y:
    if(i=='@'):
      count=count+1
  return count
      
      
data['#_@']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count =0
  for i in y:
    if(i=='@'):
      count=count+1
  return count
      
      
adata['#_@']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='@'):
      count2=count2+1
  x = count2/count
  return x
  

data['Ratio_@_Len']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='@'):
      count2=count2+1
  x = count2/count
  return x
  

adata['Ratio_@_Len']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count =0
  for i in y:
    if(i=='*'or i=='?'or  i=='!'or i =='#'or i=='$'or i=='%'  or i=='^' or i=='&' or i==';' or i==':'):
      count=count+1
  return count
      
      
data['No_of_SpclChar']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count =0
  for i in y:
    if(i=='*'or i=='?'or  i=='!'or i =='#'or i=='$'or i=='%'  or i=='^' or i=='&' or i==';' or i==':'):
      count=count+1
  return count
      
      
adata['No_of_SpclChar']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='*'or i=='?'or  i=='!'or i =='#'or i=='$'or i=='%'  or i=='^' or i=='&' or i==';' or i==':'):
      count2=count2+1
  x = count2/count
  return x
  

data['Ratio_SpeclChar_Len']= data['Raw_URL'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='*'or i=='?'or  i=='!'or i =='#'or i=='$'or i=='%'  or i=='^' or i=='&' or i==';' or i==':'):
      count2=count2+1
  x = count2/count
  return x
  

adata['Ratio_SpeclChar_Len']= adata['Raw_URL'].apply(lambda x : Count(x))

# %%
a = data.Raw_URL.str.split('://')

def Protocol(y):
  return y[0]
data['Protocol']= a.apply(lambda x : Protocol(x))

def Protocol(y):
  return y[1]
data['Raw_URL']= a.apply(lambda x : Protocol(x))

a = adata.Raw_URL.str.split('://')

def Protocol(y):
  return y[0]
adata['Protocol']= a.apply(lambda x : Protocol(x))

def Protocol(y):
  return y[1]
adata['Raw_URL']= a.apply(lambda x : Protocol(x))

# %%
a = data.Raw_URL.str.split('/')

def Protocol(y):
  return y[0]
data['Domain_Name']= a.apply(lambda x : Protocol(x))

a = adata.Raw_URL.str.split('/')

def Protocol(y):
  return y[0]
adata['Domain_Name']= a.apply(lambda x : Protocol(x))

# %%
def Count(y):
  count =0
  for i in y:
    if(i.isdigit()):
      count=count+1
  return count
         
      
data['No_of_digits_D']= data['Domain_Name'].apply(lambda x : Count(x))

def Count(y):
  count =0
  for i in y:
    if(i.isdigit()):
      count=count+1
  return count
         
      
adata['No_of_digits_D']= adata['Domain_Name'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i.isdigit()):
      count2=count2+1
  x = count2/count
  return x
  

data['Ratio_Digits_Len_D']= data['Domain_Name'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i.isdigit()):
      count2=count2+1
  x = count2/count
  return x
  

adata['Ratio_Digits_Len_D']= adata['Domain_Name'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  return count
data['D_Count_']= data['Domain_Name'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  return count
adata['D_Count_']= adata['Domain_Name'].apply(lambda x : Count(x))

# %%
#Analysis on Domain Name
def Count(y):
  count=0
  for i in y:
    if(i=='-'):
      count=count+1
  return count
data['D_#_-']= data['Domain_Name'].apply(lambda x : Count(x))

#Analysis on Domain Name
def Count(y):
  count=0
  for i in y:
    if(i=='-'):
      count=count+1
  return count
adata['D_#_-']= adata['Domain_Name'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='-'):
      count2=count2+1
  x = count2/count
  return x
  

data['Domain_Ratio_-_Len']= data['Domain_Name'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='-'):
      count2=count2+1
  x = count2/count
  return x
  

adata['Domain_Ratio_-_Len']= adata['Domain_Name'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    if(i=='.'):
      count=count+1
  return count
data['D_#_.']= data['Domain_Name'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    if(i=='.'):
      count=count+1
  return count
adata['D_#_.']= adata['Domain_Name'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='.'):
      count2=count2+1
  x = count2/count
  return x
  

data['Domain_Ratio_._Len']= data['Domain_Name'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='.'):
      count2=count2+1
  x = count2/count
  return x
  

adata['Domain_Ratio_._Len']= adata['Domain_Name'].apply(lambda x : Count(x))

# %%
data['D_Count_Mean']= data.D_Count_.mean()
adata['D_Count_Mean']= adata.D_Count_.mean()

# %%
def Count(y):
  count=1
  for i in y:
    if(i=='.' or i== '-'):
      count=count+1
  return count
data['D_Count_Token']= data['Domain_Name'].apply(lambda x : Count(x))

def Count(y):
  count=1
  for i in y:
    if(i=='.' or i== '-'):
      count=count+1
  return count
adata['D_Count_Token']= adata['Domain_Name'].apply(lambda x : Count(x))

# %%
data['D_Count_Token_mean']= data['D_Count_Token'].mean()

adata['D_Count_Token_mean']= adata['D_Count_Token'].mean()

# %%
def Count(y):
  count=0
  for i in y:
    x = re.search('[A-Z]',i)
    if(x):
      count=count+1
  return count
  


data['Domain_Caps']= data['Domain_Name'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    x = re.search('[A-Z]',i)
    if(x):
      count=count+1
  return count
  


adata['Domain_Caps']= adata['Domain_Name'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    q = re.search('[A-Z]',i)
    if(q):
      count2=count2+1
  x = count2/count
  return x
  

data['Domain_Ratio_Caps_Len']= data['Domain_Name'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    q = re.search('[A-Z]',i)
    if(q):
      count2=count2+1
  x = count2/count
  return x
  

adata['Domain_Ratio_Caps_Len']= adata['Domain_Name'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    x = re.search('[a-z]',i)
    if(x):
      count=count+1
  return count
  


data['Domain_Small']= data['Domain_Name'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    x = re.search('[a-z]',i)
    if(x):
      count=count+1
  return count
  


adata['Domain_Small']= adata['Domain_Name'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    q = re.search('[a-z]',i)
    if(q):
      count2=count2+1
  x = count2/count
  return x
  

data['Domain_Ratio_Small_Len']= data['Domain_Name'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    q = re.search('[a-z]',i)
    if(q):
      count2=count2+1
  x = count2/count
  return x
  

adata['Domain_Ratio_Small_Len']= adata['Domain_Name'].apply(lambda x : Count(x))

# %%
def Count(y):
  IP = 0
  x = re.search("^(?:[0-9]{1,3}\.){3}[0-9]{1,3}$", y)
  if(x):
    IP = 1
  if(x== None):
    IP = 0
  return IP
data['IP']= data['Domain_Name'].apply(lambda x : Count(x))

def Count(y):
  IP = 0
  x = re.search("^(?:[0-9]{1,3}\.){3}[0-9]{1,3}$", y)
  if(x):
    IP =1
  if(x== None):
    IP = 0
  return IP
adata['IP']= adata['Domain_Name'].apply(lambda x : Count(x))

# %%
a = data.Domain_Name.str.split('.')

def Protocol(y):
  return y[-1]
  
data['Top_Domain']= a.apply(lambda x : Protocol(x))

a = adata.Domain_Name.str.split('.')

def Protocol(y):
  return y[-1]
  
adata['Top_Domain']= a.apply(lambda x : Protocol(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  return count
data['TLD_Count_']= data['Top_Domain'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  return count
adata['TLD_Count_']= adata['Top_Domain'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    x = re.search('[A-Z]',i)
    if(x):
      count=count+1
  return count
  


data['TLD_Caps']= data['Top_Domain'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    x = re.search('[A-Z]',i)
    if(x):
      count=count+1
  return count
  


adata['TLD_Caps']= adata['Top_Domain'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    q = re.search('[A-Z]',i)
    if(q):
      count2=count2+1
  x = count2/count
  return x
  

data['TLD_Ratio_Caps_Len']= data['Top_Domain'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    q = re.search('[A-Z]',i)
    if(q):
      count2=count2+1
  x = count2/count
  return x
  

adata['TLD_Ratio_Caps_Len']= adata['Top_Domain'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    x = re.search('[a-z]',i)
    if(x):
      count=count+1
  return count
  


data['TLD_Small']= data['Top_Domain'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    x = re.search('[a-z]',i)
    if(x):
      count=count+1
  return count
  


adata['TLD_Small']= adata['Top_Domain'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    q = re.search('[a-z]',i)
    if(q):
      count2=count2+1
  x = count2/count
  return x
  

data['TLD_Ratio_Small_Len']= data['Top_Domain'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    q = re.search('[a-z]',i)
    if(q):
      count2=count2+1
  x = count2/count
  return x
  

adata['TLD_Ratio_Small_Len']= adata['Top_Domain'].apply(lambda x : Count(x))

# %%
def Count(y):
  count =0
  for i in y:
    if(i.isdigit()):
      count=count+1
  return count
         
      
data['No_of_digits_TLD']= data['Top_Domain'].apply(lambda x : Count(x))

def Count(y):
  count =0
  for i in y:
    if(i.isdigit()):
      count=count+1
  return count
         
      
adata['No_of_digits_TLD']= adata['Top_Domain'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i.isdigit()):
      count2=count2+1
  x = count2/count
  return x
  

data['Ratio_Digits_Len_TLD']= data['Top_Domain'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i.isdigit()):
      count2=count2+1
  x = count2/count
  return x
  

adata['Ratio_Digits_Len_TLD']= adata['Top_Domain'].apply(lambda x : Count(x))

# %%
def Split(y):
  a = y.split('.')
  return a

data['Words_Domain']= data['Domain_Name'].apply(lambda x : Split(x))

def Split(y):
  a = y.split('.')
  return a

adata['Words_Domain']= adata['Domain_Name'].apply(lambda x : Split(x))

# %%
def Count(y):
  count=0
  k=0
  for i in y:
    count=len(i)+count
    k=k+1
  x = count/k
  return x

data['Avg_length_token']= data['Words_Domain'].apply(lambda x : Count(x))

def Count(y):
  count=0
  k=0
  for i in y:
    count=len(i)+count
    k=k+1
  x = count/k
  return x

adata['Avg_length_token']= adata['Words_Domain'].apply(lambda x : Count(x))

# %%
def find_the_longest_word(x):
  
  new_arr = x.split('.')
  return ((max(new_arr, key=len)))

data['Longest_word_Domain']= data['Domain_Name'].apply(lambda x : find_the_longest_word(x))

def find_the_longest_word(x):
  
  new_arr = x.split('.')
  return ((max(new_arr, key=len)))

adata['Longest_word_Domain']= adata['Domain_Name'].apply(lambda x : find_the_longest_word(x))

# %%
def find_the_smallest_word(x):
  
  new_arr = x.split('.')
  return ((min(new_arr, key=len)))

data['Smallest_word_Domain']= data['Domain_Name'].apply(lambda x : find_the_smallest_word(x))

def find_the_smallest_word(x):
  
  new_arr = x.split('.')
  return ((min(new_arr, key=len)))

adata['Smallest_word_Domain']= adata['Domain_Name'].apply(lambda x : find_the_smallest_word(x))

# %%
def find_the_len_longest_word(y):
  # recusion to skip over symbols
  new_arr = y.split('.')
  return (len(max(new_arr, key=len)))

data['Len_Longest_Dom']= data['Domain_Name'].apply(lambda x : find_the_len_longest_word(x))

def find_the_len_longest_word(y):
  # recusion to skip over symbols
  new_arr = y.split('.')
  return (len(max(new_arr, key=len)))

adata['Len_Longest_Dom']= adata['Domain_Name'].apply(lambda x : find_the_len_longest_word(x))

# %%
def find_the_len_smallest_word(y):
  # recusion to skip over symbols
  new_arr = y.split('.')
  return (len(min(new_arr, key=len)))

data['Len_smallest_Dom']= data['Domain_Name'].apply(lambda x : find_the_len_smallest_word(x))

def find_the_len_smallest_word(y):
  # recusion to skip over symbols
  new_arr = y.split('.')
  return (len(min(new_arr, key=len)))

adata['Len_smallest_Dom']= adata['Domain_Name'].apply(lambda x : find_the_len_smallest_word(x))

# %%
data['Mean_length_longest']=data['Len_Longest_Dom'].mean()

adata['Mean_length_longest']=adata['Len_Longest_Dom'].mean()

# %%
def Count(y):
  count =0
  for i in y:
    if(i=='*'or i=='?'or i=='@'or i=='!'or i =='#'or i=='$'or i=='%'  or i=='^' or i=='&'):
      count=count+1
  return count
      
      
data['No_of_SpclChar_D']= data['Domain_Name'].apply(lambda x : Count(x))

def Count(y):
  count =0
  for i in y:
    if(i=='*'or i=='?'or i=='@'or i=='!'or i =='#'or i=='$'or i=='%'  or i=='^' or i=='&'):
      count=count+1
  return count
      
      
adata['No_of_SpclChar_D']= adata['Domain_Name'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='*'or i=='?'or i=='@'or i=='!'or i =='#'or i=='$'or i=='%'  or i=='^' or i=='&'):
      count2=count2+1
  x = count2/count
  return x
  

data['Domain_Ratio_Splchar_Len']= data['Domain_Name'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    count=count+1
  count2=0
  for i in y:
    if(i=='*'or i=='?'or i=='@'or i=='!'or i =='#'or i=='$'or i=='%'  or i=='^' or i=='&'):
      count2=count2+1
  x = count2/count
  return x
  

adata['Domain_Ratio_Splchar_Len']= adata['Domain_Name'].apply(lambda x : Count(x))

# %%
a = data.Raw_URL.str.split('/')

def Count(y):
  k = len(y)
  return k-1

data['Path_length'] = a.apply(lambda x : Count(x))

a = adata.Raw_URL.str.split('/')

def Count(y):
  k = len(y)
  return k-1

adata['Path_length'] = a.apply(lambda x : Count(x))

# %%
a = data.Raw_URL.str.split('/')

def Path_elements(y):
  k = y[1:]
  return k

data['Path_elements'] = a.apply(lambda x : Path_elements(x))

a = adata.Raw_URL.str.split('/')

def Path_elements(y):
  k = y[1:]
  return k

adata['Path_elements'] = a.apply(lambda x : Path_elements(x))

# %%
def Count(y):
  count=0
  for i in y:
    for j in i:
      count=count+1
  return count
data['Element_count']= data['Path_elements'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    for j in i:
      count=count+1
  return count
adata['Element_count']= adata['Path_elements'].apply(lambda x : Count(x))

# %%
def Count(y):
  count =0  
  for j in y:
    for i in j:
      if(i=='*'or i=='?'or i=='@'or i=='!'or i =='#'or i=='$'or i=='%'  or i=='^' or i=='&' or i=='='):
        count=count+1
  return count

data['Special_Char_Path']= data['Path_elements'].apply(lambda x : Count(x))

def Count(y):
  count =0  
  for j in y:
    for i in j:
      if(i=='*'or i=='?'or i=='@'or i=='!'or i =='#'or i=='$'or i=='%'  or i=='^' or i=='&' or i=='='):
        count=count+1
  return count

adata['Special_Char_Path']= adata['Path_elements'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    for j in i:
      count=count+1
  count2=0
  for j in y:
    for i in j:
      if(i=='*'or i=='?'or  i=='!'or i =='#'or i=='$'or i=='%'  or i=='^' or i=='&' or i==';' or i==':'):
        count2=count2+1
  x=0
  if(count!=0):
    x = count2/count
  return x
  

data['Ratio_SpeclChar_Len_path']= data['Path_elements'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    for j in i:
      count=count+1
  count2=0
  for j in y:
    for i in j:
      if(i=='*'or i=='?'or  i=='!'or i =='#'or i=='$'or i=='%'  or i=='^' or i=='&' or i==';' or i==':'):
        count2=count2+1
  x=0
  if(count!=0):
    x = count2/count
  return x
  

adata['Ratio_SpeclChar_Len_path']= adata['Path_elements'].apply(lambda x : Count(x))

# %%
def Path_elements(y):
  x = 0
  k = 0
  for q in y:
    k = k+1
  
  if(k!=0):
    count =0
    for j in y:
      for i in j:
        if(i=='*'or i=='?'or i=='@'or i=='!'or i =='#'or i=='$'or i=='%'  or i=='^' or i=='&' or i=='='):
          count=count+1
    x =count/k
  return x
  
  

data['Avg_SplChar_PathElements'] = data['Path_elements'].apply(lambda x : Path_elements(x))



def Path_elements(y):
  x = 0
  k = 0
  for q in y:
    k = k+1
  
  if(k!=0):
    count =0
    for j in y:
      for i in j:
        if(i=='*'or i=='?'or i=='@'or i=='!'or i =='#'or i=='$'or i=='%'  or i=='^' or i=='&' or i=='='):
          count=count+1
    x =count/k
  return x
  
  

adata['Avg_SplChar_PathElements'] = adata['Path_elements'].apply(lambda x : Path_elements(x))

# %%
def Count(y):
  count=0
  for i in y:
    for j in i:
      x = re.search('[A-Z]',i)
      if(x):
        count=count+1
  return count
  
data['Elements_Caps']= data['Path_elements'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    for j in i:
      x = re.search('[A-Z]',i)
      if(x):
        count=count+1
  return count
  
adata['Elements_Caps']= adata['Path_elements'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    for j in i:
      x = re.search('[a-z]',i)
      if(x):
        count=count+1
  return count
  
data['Elements_Small']= data['Path_elements'].apply(lambda x : Count(x))

def Count(y):
  count=0
  for i in y:
    for j in i:
      x = re.search('[a-z]',i)
      if(x):
        count=count+1
  return count
  
adata['Elements_Small']= adata['Path_elements'].apply(lambda x : Count(x))

# %%
def Count(y):
  count=0
  for i in y:
    x=re.search('http',i)
    if(x):
      count=count+1
  return count
       
data['#_http'] = data['Path_elements'].apply(lambda x : Count(x))


def Count(y):
  count=0
  for i in y:
    x=re.search('http',i)
    if(x):
      count=count+1
  return count
       
adata['#_http'] = adata['Path_elements'].apply(lambda x : Count(x))

# %%
data['Type_URL']='Phishing'
adata['Type_URL']='Spam'

# %%
Data.head(5)
# Out:
#                                              Raw_URL  Len_URL  ...  #_http  Type_URL
# 0  v2.email-marketing.adminsimple.com/track/link?...      294  ...       1         0
# 1  bid.openx.net/json?amp;amp;amp;amp;cid;=oxpv1:...      292  ...       0         0
# 2  webmail2.centurytel.net/hwebmail/services/go.p...      288  ...       1         0
# 3               www.google.com.ng/imgres?imgurl=http      287  ...       1         0
# 4  webmail2.centurytel.net/hwebmail/services/go.p...      286  ...       1         0
#
# [5 rows x 63 columns]

# %%
frames = [data, adata]
Data = pd.concat(frames)

# %%
def url(y):
  dic={'Phishing':0, 'Spam':1}
  x = dic.get(y)
  return x


Data['Type_URL']= Data['Type_URL'].apply(lambda x : url(x))

# %%
y = Data['Type_URL']
X = Data.drop(['Raw_URL', 'Protocol', 'Domain_Name', 'Top_Domain', 'Words_Domain', 'Longest_word_Domain', 	'Smallest_word_Domain', 'Path_elements','Type_URL'], axis=1)

# %%
X.head()
# Out:
#    Len_URL  #_/  Ratio_/_Len  ...  Elements_Caps  Elements_Small  #_http
# 0      294    4     0.013605  ...            246             251       1
# 1      292    9     0.030822  ...              0             265       0
# 2      288   12     0.041667  ...              0              31       1
# 3      287   13     0.045296  ...              0              18       1
# 4      286   11     0.038462  ...              0              31       1
#
# [5 rows x 54 columns]

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot
from sklearn.metrics import confusion_matrix
from termcolor import colored

# %%
# split data into train and test sets
seed = 7
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)

# %%
#XGB
model = XGBClassifier(silent=False, 
                      scale_pos_weight=1,
                      learning_rate=0.01,  
                      colsample_bytree = 0.4,
                      subsample = 0.8,
                      objective='binary:logistic', 
                      n_estimators=100, 
                      reg_alpha = 0.3,
                      max_depth=4,gamma=5)


eval_set = [(X_train, y_train), (X_test, y_test)]
model.fit(X_train, y_train,eval_metric=["error", "logloss", "auc"], eval_set=eval_set, verbose=True)
print(model)
# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# [0]	validation_0-error:0	validation_0-logloss:0.683204	validation_0-auc:1	validation_1-error:0	validation_1-logloss:0.683204	validation_1-auc:1
# [1]	validation_0-error:0	validation_0-logloss:0.673457	validation_0-auc:1	validation_1-error:0	validation_1-logloss:0.673457	validation_1-auc:1
# [2]	validation_0-error:0	validation_0-logloss:0.663901	validation_0-auc:1	validation_1-error:0	validation_1-logloss:0.663901	validation_1-auc:1
# [3]	validation_0-error:0	validation_0-logloss:0.654531	validation_0-auc:1	validation_1-error:0	validation_1-logloss:0.654531	validation_1-auc:1
# [4]	validation_0-error:0	validation_0-logloss:0.645341	validation_0-auc:1	validation_1-error:0	validation_1-logloss:0.645341	validation_1-auc:1
# [5]	validation_0-error:0	validation_0-logloss:0.63828	validation_0-auc:1	validation_1-error:0	validation_1-logloss:0.638376	validation_1-auc:1
# ...

# %%
#Prediction on validation set
y_pred = model.predict(X_test)

# Making the Confusion Matrix
cm = confusion_matrix(y_test, (y_pred>0.5))
print(colored('The Confusion Matrix is: ', 'red'),'\n', cm)
# Out:
# The Confusion Matrix is:
#  [[1934    0]
#  [   0 2459]]

# %%
#Logistic_Regression
clf = LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial').fit(X_train, y_train)
y_pred = clf.predict(X_test)
predictions = [round(value) for value in y_pred]

# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 97.93%
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
4
